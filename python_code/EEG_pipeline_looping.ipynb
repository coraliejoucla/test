# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import sys
import glob, os
import papermill as pm

# %%
# List of data files to process
data_files = glob.glob('D:/RAW DATA/2021-own-name-revcor/EEG/*.vhdr')

# Loop over data files
for num, eeg_file in enumerate(data_files):
    print(num)
#     if num!=2:
#         print('done already')
#     else:
    # Execute the notebook with the current data file 
    pm.execute_notebook(
        input_path='EEG_preprocessing_new.ipynb',
        output_path='output_notebook.ipynb',
        log_output=True,
        parameters={"eeg_file": eeg_file}
    )
# Out:
# 0
# Executing:   0%|          | 0/67 [00:00<?, ?cell/s]
# C:\Program Files\Python310\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
#
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
#
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed:    4.1s finished
#
# [Parallel(n_jobs=16)]: Using backend LokyBackend with 16 concurrent workers.
#
# [Parallel(n_jobs=16)]: Done   3 out of  16 | elapsed:    2.4s remaining:   10.7s
# ...
